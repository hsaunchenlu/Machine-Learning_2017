# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


A = np.array([6.27114898629,6.14950997156,6.12795533639,6.12302])
B = np.array([6.20427,5.79281,5.86315,5.79969])
X = np.array([471,471*5,571*8,471*12])
print(X)
plt1 = plt.plot(X,A,'b',label ='Training' )
plt2 = plt.plot(X,B,'r',label ='Testing(pub)')
#plt.title('')
plt.legend()
plt.ylabel('RMSE')
plt.xlabel('')
plt.savefig('itermstest.pmng',dpi = 300,format = 'png')
plt.show()
# Out:
# [ 471 2355 4568 5652]
