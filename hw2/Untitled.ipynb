# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
lamda = np.log10([0,0.00001,0.0001,0.001,0.01,0.1,1])
kpb = [0.85172,0.85332,0.85418,0.85270,0.85233,0.85111,0.84324]
kpr = [0.85076,0.85100,0.85100,0.85137,0.85125,0.85186,0.84633]

plt.plot(lamda,kpb)
plt.plot(lamda,kpr)
plt.show()
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
